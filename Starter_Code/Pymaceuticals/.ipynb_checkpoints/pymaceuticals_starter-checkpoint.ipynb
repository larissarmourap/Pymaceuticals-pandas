# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# The correlation between mouse weight and the average is a positive correlation with a tumor volume of 0.84.
# Once we removed the duplicates the total number of mice is 248.
# The total count of mice by gender also showed that 123.008 female mice and 124.992 male mice

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from pathlib import Path
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
pymaceuticals_complete = pd.merge(mouse_metadata, study_results, how="outer", on = "Mouse ID")
# Display the data table for preview
pymaceuticals_complete
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
checking_numbers = len(pymaceuticals_complete['Mouse ID'].unique())
checking_numbers
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate = pymaceuticals_complete.loc[pymaceuticals_complete.duplicated(['Mouse ID', 'Timepoint']), 'Mouse ID'].unique()
duplicate
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_df = pymaceuticals_complete.loc[pymaceuticals_complete["Mouse ID"] == "g989", :]
duplicate_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
new_data = pymaceuticals_complete[pymaceuticals_complete['Mouse ID'].isin(duplicate)==False]
new_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
new_checking_mice = new_data['Mouse ID'].nunique()
new_checking_mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
mean =  new_data['Tumor Volume (mm3)'].groupby(new_data['Drug Regimen']).mean()
median = new_data['Tumor Volume (mm3)'].groupby(new_data['Drug Regimen']).median()
variance = new_data['Tumor Volume (mm3)'].groupby(new_data['Drug Regimen']).var()
sd_dv = new_data['Tumor Volume (mm3)'].groupby(new_data['Drug Regimen']).std()
sem = new_data['Tumor Volume (mm3)'].groupby(new_data['Drug Regimen']).sem()
# Assemble the resulting series into a single summary DataFrame.
summary_df = pd.DataFrame({"Mean" : mean, 
                           "Median": median, 
                           "Variance": variance, 
                           "Standard Deviation": sd_dv, 
                           "SEM": sem})
summary_df
# Out:
#                    Mean     Median   Variance  Standard Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764            4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177            6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684            6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577            8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479            8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083            7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013            6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704            4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562            7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355            6.966589  0.516398

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)
# Using the aggregation method, produce the same summary statistics in a single line
summary =  new_data.groupby(['Drug Regimen'])[['Tumor Volume (mm3)']].agg(['mean', 'median', 'var', 'std', 'sem'])
summary
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
count_mice = new_data.groupby("Drug Regimen")[["Mouse ID","Timepoint"]].count()
plot_pandas = count_mice.plot.bar(figsize=(15,10), color='b''c',fontsize = 14)
count_mice
plt.xlabel("Drug Regimen",fontsize = 14)
plt.ylabel("Number of Mice",fontsize = 14)
plt.title("Total Numbers per Regime",fontsize = 20)

plt.show()

count_mice
# Out:
#               Mouse ID  Timepoint
# Drug Regimen
# Capomulin          230        230
# Ceftamin           178        178
# Infubinol          178        178
# Ketapril           188        188
# Naftisol           186        186
# Placebo            181        181
# Propriva           148        148
# Ramicane           228        228
# Stelasyn           181        181
# Zoniferol          182        182

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
count_mice = new_data.groupby("Drug Regimen")[["Mouse ID","Timepoint"]].count()
count_mice = count_mice.iloc[:,0]
x_axis = np.arange(len(count_mice))
plt.bar(x_axis, count_mice , color='r', alpha=0.3, align="center")
plt.title("Total Numbers per Regime")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mice_sex = new_data.groupby("Sex")[["Mouse ID"]].nunique()
explode = (0.1, 0)
mice_sex_chart = mice_sex["Mouse ID"].plot(
    kind="pie",label="", title="Mice per Sex", labels=mice_sex.index, autopct='%1.1f%%',explode = explode, shadow=True, legend=False,startangle=120,colors=["red","green"])

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
fig1, ax1 = plt.subplots()
explode = (0.1, 0)
ax1.pie(mice_sex["Mouse ID"], labels=mice_sex.index, autopct='%1.1f%%',explode = explode, shadow=True, startangle=120,colors=["orange","blue"])
plt.title("Mice per Sex")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:
# Capomulin, Ramicane, Infubinol, and Ceftamin  
drug_list = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
drugs = new_data[new_data["Drug Regimen"].isin(drug_list)]

# %%
# Start by getting the last (greatest) timepoint for each mouse
last_timepoint = drugs.groupby(["Drug Regimen", "Mouse ID"]).agg(tumor_size=("Tumor Volume (mm3)", lambda x: x.iloc[-1]))
last_timepoint = last_timepoint.stack(level=0).unstack(level=0)
for drug in drug_list:
    print(drug)
# Out:
# Capomulin
# Ramicane
# Infubinol
# Ceftamin

# %%
treatment = 0
for drug in drug_list:
    quartiles = last_timepoint[drug].quantile([.25,.5,.75]).round(2)
    lowerq = quartiles[0.25].round(2)
    upperq = quartiles[0.75].round(2)
    iqr = round(upperq-lowerq,2)
    lower_bound = round(lowerq - (1.5*iqr),2)
    upper_bound = round(upperq + (1.5*iqr),2)


    if treatment == 0:
        print(f"---------------------------------------------------------------")
    print(f"The upper quartile of {drug} treatments is: {upperq}")
    print(f"The lower quartile of {drug} treatments is: {lowerq}")
    print(f"The interquartile range of {drug} treatments is: {iqr}")
    print(f"Values below {lower_bound} could be {drug} outliers.")
    print(f"Values above {upper_bound} could be {drug} outliers.")
    print(f"--------------------------------------------------------------------")
    treatment+=1
# Out:
# ---------------------------------------------------------------
# The upper quartile of Capomulin treatments is: 40.16
# The lower quartile of Capomulin treatments is: 32.38
# The interquartile range of Capomulin treatments is: 7.78
# Values below 20.71 could be Capomulin outliers.
# Values above 51.83 could be Capomulin outliers.
# --------------------------------------------------------------------
# The upper quartile of Ramicane treatments is: 40.66
# The lower quartile of Ramicane treatments is: 31.56
# The interquartile range of Ramicane treatments is: 9.1
# Values below 17.91 could be Ramicane outliers.
# Values above 54.31 could be Ramicane outliers.
# --------------------------------------------------------------------
# The upper quartile of Infubinol treatments is: 65.53
# The lower quartile of Infubinol treatments is: 54.05
# The interquartile range of Infubinol treatments is: 11.48
# Values below 36.83 could be Infubinol outliers.
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
boxplot_list = []
for drug in drug_list:
    boxplot_list.append(list(last_timepoint[drug].dropna()))
fig = plt.figure()
plt.xlabel("Regimen")
plt.xticks([1,2,3,4], drug_list, rotation=45)
plt.ylabel("Tumor Volume")
plt.title("Tumor Volume by Drug Regimen")
plt.boxplot(boxplot_list)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
capomulin_mouse = Capomulin_df.loc[Capomulin_df["Mouse ID"] == "l509",:]
x_axis = forline_df["Timepoint"]
tumsiz = forline_df["Tumor Volume (mm3)"]

fig1, ax1 = plt.subplots()
plt.title('Capomulin treatmeant of mouse l509')
plt.plot(x_axis, tumsiz,linewidth=2, markersize=8,marker="o",color="green")
plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
capomulin_regime = new_data.loc[new_data["Drug Regimen"]=="Capomulin",:].groupby("Mouse ID")[["Weight (g)","Tumor Volume (mm3)"]].mean()
plt.scatter(capomulin_regime["Weight (g)"],capomulin_regime["Tumor Volume (mm3)"],color="g")
plt.title("Weight vs Avg Tumor Vol")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Avg Tumor Volume (mm3)")
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen
correlation = st.pearsonr(capomulin_regime['Weight (g)'],capomulin_regime['Tumor Volume (mm3)'])
print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")
exemple = st.linregress(capomulin_regime['Weight (g)'],capomulin_regime['Tumor Volume (mm3)'])
exemple
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
# LinregressResult(slope=0.9544396890241049, intercept=21.552160532685008, rvalue=0.8419363424694721, pvalue=1.3225722434712404e-07, stderr=0.12754359033201323, intercept_stderr=2.5909876867683455)

# %%
#capomulin_regime in weight (g)(average)
mslope = 0.9544396890241045
bintercept = 21.552160532685015

# %%
y_values = capomulin_regime['Weight (g)']*mslope+bintercept
plt.scatter(capomulin_regime['Weight (g)'],capomulin_regime['Tumor Volume (mm3)'])
plt.plot(capomulin_regime['Weight (g)'],y_values,color="red")
plt.title("Weight vs Average Tumor Volume")
plt.xlabel('Weight(g)')
plt.ylabel('Average Tumore Volume (mm3)')

plt.savefig('linearregression')
plt.show()
